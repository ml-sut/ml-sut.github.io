# %% [markdown]
# # Personal Data
# Please fill in your details below to help us keep track of your submission.

# %% [markdown]
# Student Name: `here`
#
# Student ID: `here`

# %% [markdown]
# # Linear Discriminant Analysis
#
# Linear Discriminant Analysis (LDA) is a classification and dimensionality reduction method to find a linear combination of features which are used to separate two or more classes.
#
# In this assignment, you will implement a LDA class from scratch and use it to find the bounderies to separate two and more classes.

# %% [markdown]
# # Classification on Two classes (65 points)
# # Step 1: Data Exploration
# The dataset which is used in this part is several game result predictor which are independent variables and one target, dependent variable, called : `win_or_defeat`.
#
# Note that in the cells where you need to display a chart, it is not necessary to follow the exact style of the chart.

# %%
# !pip install typing-extensions --upgrade
# !pip install ydata-profiling
# !pip install gdown
# Out:
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (4.12.2)
# Requirement already satisfied: ydata-profiling in /usr/local/lib/python3.11/dist-packages (4.12.2)
# Requirement already satisfied: scipy<1.16,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (1.13.1)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (2.2.2)
# Requirement already satisfied: matplotlib>=3.5 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic>=2 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (2.10.6)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (6.0.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (3.1.5)
# Requirement already satisfied: visions<0.8.0,>=0.7.5 in /usr/local/lib/python3.11/dist-packages (from visions[type_image_path]<0.8.0,>=0.7.5->ydata-profiling) (0.7.6)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (1.26.4)
# Requirement already satisfied: htmlmin==0.1.12 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (0.14.4)
# Requirement already satisfied: typeguard<5,>=3 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (4.4.2)
# Requirement already satisfied: imagehash==4.3.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (1.9.4)
# Requirement already satisfied: dacite>=1.8 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.11/dist-packages (from imagehash==4.3.1->ydata-profiling) (1.8.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from imagehash==4.3.1->ydata-profiling) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->ydata-profiling) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->ydata-profiling) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->ydata-profiling) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->ydata-profiling) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->ydata-profiling) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->ydata-profiling) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2025.1)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.11/dist-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata-profiling) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata-profiling) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (2025.1.31)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.1)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.11/dist-packages (from visions<0.8.0,>=0.7.5->visions[type_image_path]<0.8.0,>=0.7.5->ydata-profiling) (25.1.0)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.11/dist-packages (from visions<0.8.0,>=0.7.5->visions[type_image_path]<0.8.0,>=0.7.5->ydata-profiling) (3.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5->ydata-profiling) (1.17.0)
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown) (4.13.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown) (3.17.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2025.1.31)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.metrics import accuracy_score
from scipy.linalg import eigh as sp_eigh
from sklearn.feature_selection import mutual_info_classif, RFE

# %% [markdown]
# ### First, download the dataset.

# %%
# !gdown 1SGuWqcRJ1GvPO9RxzxjOAkCEN_RDJY9d
# !wget -O dataset.csv "https://drive.google.com/file/d/1SGuWqcRJ1GvPO9RxzxjOAkCEN_RDJY9d/view?usp=sharing"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1SGuWqcRJ1GvPO9RxzxjOAkCEN_RDJY9d
# To: /content/train.csv
# 100% 493k/493k [00:00<00:00, 114MB/s]
# --2025-03-02 19:27:11--  https://drive.google.com/file/d/1SGuWqcRJ1GvPO9RxzxjOAkCEN_RDJY9d/view?usp=sharing
# Resolving drive.google.com (drive.google.com)... 142.251.8.139, 142.251.8.101, 142.251.8.113, ...
# Connecting to drive.google.com (drive.google.com)|142.251.8.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘dataset.csv’
#
# dataset.csv             [ <=>                ]  92.83K   615KB/s    in 0.2s
#
# 2025-03-02 19:27:13 (615 KB/s) - ‘dataset.csv’ saved [95055]

# %% [markdown]
# Load the dataset as a dataframe. Then do the following. (5 points)
# - Drop datas with null values.
# - Do duplicate detection and drop them.
# - Report Kurtosis.
# - Report Interquartile range (IQR).
# - Display the first 10 rows.
# - Search and read about ydata-profiling, apply it to data and save the result in "report.html".

# %%
# TODO: Load the dataset as a pandas dataframe
df = None

# TODO: Drop rows with null values from the dataframe
df = None # 📣

# TODO: Detect and drop duplicate rows from the dataframe
df = None # 📣

# TODO: Calculate and print the kurtosis of the dataframe (numeric columns only)
kurtosis = None # 📣
print(kurtosis)

# TODO: Select only numeric columns (int and float64) from the dataframe
non_obj = None # 📣

# TODO: Calculate the Interquartile Range (IQR) for the numeric columns
q3, q1 = None # 📣
print(q3 - q1)

# TODO: Display the first 10 rows of the dataframe
df.head(None)

# TODO: Search and read about ydata-profiling
# TODO: Generate a profile report for the dataframe and save it as "report.html"
from ydata_profiling import ProfileReport
report = None # 📣
report.to_file(None)
# Out:
# Unnamed: 0              -1.199976
# spell_used              -0.771228
# trap_used               -1.560519
# assists                  1.796163
# damage_amount           20.631801
# towers_damage            3.060186
# rooms_damage            20.631801
# deaths                   0.372563
# money_total              0.326406
# kill_death_ratio         9.973199
# kills_total              1.438422
# level                   -0.384155
# controlling_time        11.943538
# total_damage             0.696798
# earned_damage            1.792284
# special_enemy_killed    -1.157044
# room_kills               2.527769
# main_score               3.950108
# win_or_defeat           -1.999972
# dtype: float64
# 3314.75
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ### For any column which is numerical print mean, standard deviation, maximum and minimum values. (3 points)

# %%
print("mean values:----------------------------------")
# TODO
print(mean_values)
print("std  values:----------------------------------")
# TODO
print(std_values)
print("max values:-----------------------------------")
# TODO
print(max_values)
print("min values:-----------------------------------")
# TODO
print(min_values)
# Out:
# mean values:----------------------------------
# Unnamed: 0                2308.996098
# spell_used                   6.707782
# trap_used                    8.430739
# assists                      8.189031
# damage_amount             2639.487752
# towers_damage             9382.315847
# rooms_damage              2639.487752
# deaths                       5.740733
# money_total              10865.129850
# kill_death_ratio             3.602712
# kills_total                  5.702580
# level                       13.826794
# controlling_time            18.926295
# total_damage            117652.268806
# earned_damage            21465.087145
# special_enemy_killed       120.789725
# room_kills                   1.032517
# main_score                  30.158899
# dtype: float64
# std  values:----------------------------------
# Unnamed: 0               1331.809470
# spell_used                  3.976734
# trap_used                   4.312468
# assists                     5.639756
# damage_amount            3194.783198
# towers_damage           10101.251927
# rooms_damage             3194.783198
# deaths                      3.020094
# money_total              3473.747695
# kill_death_ratio            3.767723
# kills_total                 4.317011
# level                       2.373998
# controlling_time           14.080420
# total_damage            70408.498868
# earned_damage            9907.871328
# special_enemy_killed       83.739102
# room_kills                  1.313180
# main_score                 20.875652
# dtype: float64
# max values:-----------------------------------
# Unnamed: 0                4615.0
# spell_used                  21.0
# trap_used                   21.0
# assists                     41.0
# damage_amount            44162.0
# towers_damage            68474.0
# rooms_damage             44162.0
# deaths                      21.0
# money_total              28566.0
# kill_death_ratio            33.0
# kills_total                 30.0
# level                       18.0
# controlling_time           193.0
# total_damage            499423.0
# earned_damage            78861.0
# special_enemy_killed       440.0
# room_kills                   9.0
# main_score                 174.0
# dtype: float64
# min values:-----------------------------------
# Unnamed: 0                 0.0
# spell_used                 1.0
# trap_used                  1.0
# assists                    0.0
# damage_amount              0.0
# towers_damage              0.0
# rooms_damage               0.0
# deaths                     0.0
# money_total             3093.0
# kill_death_ratio           0.0
# kills_total                0.0
# level                      6.0
# controlling_time           0.0
# total_damage            5401.0
# earned_damage           2674.0
# special_enemy_killed       0.0
# room_kills                 0.0
# main_score                 1.0
# dtype: float64

# %% [markdown]
# ### Print number of unique values for `location` column. (2 points)

# %%
# TODO
# Out:
# location
# Lane.jungle      978
# Lane.top_lane    955
# Lane.mid_lane    913
# Lane.bot_lane    902
# Lane.utility     865
# Name: count, dtype: int64

# %% [markdown]
# ### Show correlation matrix. (3 points)

# %%
# TODO: Calculate the correlation matrix for numerical features
correlation_matrix = None # 📣

# TODO: Plot the correlation matrix as a heatmap
# hint: Use seaborn to create a heatmap with annotations
plt.figure(figsize=(12, 6))
# 📣 # plot heatmap
# Out:
# <Axes: >

# %% [markdown]
# ### Plot barplot of combined `position` and `location`. (3 points)
# Position on x axis and location on legend.

# %%
# TODO

# %% [markdown]
# ### Plor pie chart for `level`. (3 points)

# %%
# TODO: Get the value counts for the 'level' column
details = None

# TODO: Get label and size from it
labels = []
sizes = []

# TODO: pie plot!

# %% [markdown]
# ### Use box plox to see relation between `location` and `earned_damage`. (2 points)

# %%
# TODO # 📣
# Out:
# <Axes: xlabel='location', ylabel='earned_damage'>

# %% [markdown]
# ### Plot hist plot of `spell_used`. (2 points)

# %%
# TODO
# Out:
# <Axes: xlabel='spell_used', ylabel='Count'>

# %% [markdown]
# ## Step2: Preprocessing of Data
# To give the data to our model, first we have to apply some prerocessing fucntion on it to make it ready for model.

# %% [markdown]
# # Feature Selection
# In data science, data often has many features. But not all of these features are necessarily helpful because some of them do not provide useful information. Therefore, we need methods that, according to the nature of the data, extract the necessary features so that we can use them to solve our problem.
#
# ## Question: (3 points)
# Find and explain some of this feature selection techniques (e.g. mutual information).
#
# ## `Answer`

# %% [markdown]
# ### Drop the features which have low correlation with target varibale. (5 points)

# %%
# TODO: Drop features with correlation less than 0.015 with the target variable # 📣

df.head(10)
# Out:
#     trap_used    character   position       location  assists  damage_amount  \
# 0          12  TwistedFate  Side.blue  Lane.top_lane      9.0           1862
# 2          12        Ziggs  Side.blue  Lane.bot_lane      3.0            543
# 3           7        Senna   Side.red  Lane.bot_lane      4.0           1547
# 5          11       Rengar   Side.red    Lane.jungle      7.0           1564
# 6          12        Ziggs  Side.blue  Lane.bot_lane      9.0          19665
# 7          14        Karma  Side.blue   Lane.utility      4.0            740
# 8           4         Zyra   Side.red   Lane.utility      8.0              0
# 9          12       Graves   Side.red  Lane.mid_lane      5.0           3277
# 10          4         Olaf  Side.blue    Lane.jungle      3.0              0
# 11         12         Kled   Side.red  Lane.top_lane      3.0           3646
#
#     towers_damage  rooms_damage  deaths  money_total  kill_death_ratio  \
# 0            5119          1862       9         9152          1.222222
# 2            2754           543       4         9014          1.750000
# 3            1547          1547       6         8155          1.000000
# 5           16053          1564       4        11536          3.500000
# 6           20431         19665       3        10699          5.333333
# 7             997           740       1         5469          5.000000
# 8             123             0      10         7371          0.900000
# 9            3277          3277       5         9270          1.800000
# 10           7063             0      10         8514          0.500000
# 11           4463          3646      11        10220          0.636364
#
#     kills_total  level  controlling_time  total_damage  earned_damage  \
# 0             2     13                19         99079          25062
# 2             4     12                11        106757          10049
# 3             2     12                14         53993          12480
# 5             7     14                14        128646          40236
# 6             7     12                11        123192           8057
# 7             1     10                17         18138           3414
# 8             1     12                49         32425          24632
# 9             4     12                19        109150          13704
# 10            2     13                12        106474          38614
# 11            4     14                 7        119522          41289
#
#     special_enemy_killed  room_kills  main_score  win_or_defeat
# 0                    149           1          21          False
# 2                    168           0          11          False
# 3                    129           1          11          False
# 5                     27           1          17           True
# 6                    140           4           9           True
# 7                     25           0          38          False
# 8                     30           0          91          False
# 9                    162           1          15          False
# 10                    19           0          29          False
# 11                   178           0          13          False

# %% [markdown]
# ### Encode the labels (5 points)
# Use sklearn LabelEncoder to encode the non-numerical columns. Cast the label column to numeric type.

# %%
# TODO: Encode categorical columns using LabelEncoder # 📣

df.head(10)
# Out:
#     trap_used  character  position  location  assists  damage_amount  \
# 0          12        129         0         3      9.0           1862
# 2          12        153         0         0      3.0            543
# 3           7        105         1         0      4.0           1547
# 5          11         99         1         1      7.0           1564
# 6          12        153         0         0      9.0          19665
# 7          14         52         0         4      4.0            740
# 8           4        156         1         4      8.0              0
# 9          12         37         1         2      5.0           3277
# 10          4         86         0         1      3.0              0
# 11         12         61         1         3      3.0           3646
#
#     towers_damage  rooms_damage  deaths  money_total  kill_death_ratio  \
# 0            5119          1862       9         9152          1.222222
# 2            2754           543       4         9014          1.750000
# 3            1547          1547       6         8155          1.000000
# 5           16053          1564       4        11536          3.500000
# 6           20431         19665       3        10699          5.333333
# 7             997           740       1         5469          5.000000
# 8             123             0      10         7371          0.900000
# 9            3277          3277       5         9270          1.800000
# 10           7063             0      10         8514          0.500000
# 11           4463          3646      11        10220          0.636364
#
#     kills_total  level  controlling_time  total_damage  earned_damage  \
# 0             2     13                19         99079          25062
# 2             4     12                11        106757          10049
# 3             2     12                14         53993          12480
# 5             7     14                14        128646          40236
# 6             7     12                11        123192           8057
# 7             1     10                17         18138           3414
# 8             1     12                49         32425          24632
# 9             4     12                19        109150          13704
# 10            2     13                12        106474          38614
# 11            4     14                 7        119522          41289
#
#     special_enemy_killed  room_kills  main_score  win_or_defeat
# 0                    149           1          21              0
# 2                    168           0          11              0
# 3                    129           1          11              0
# 5                     27           1          17              1
# 6                    140           4           9              1
# 7                     25           0          38              0
# 8                     30           0          91              0
# 9                    162           1          15              0
# 10                    19           0          29              0
# 11                   178           0          13              0

# %% [markdown]
# ### Normalize the dataset. (5 points)

# %%
# TODO: Normalize the dataset using StandardScaler
from sklearn.preprocessing import StandardScaler

df.head(10)
# Out:
#     trap_used  character  position  location   assists  damage_amount  \
# 0    0.827751   1.135156 -0.985152  0.731026  0.143811      -0.243388
# 2    0.827751   1.671426 -0.985152 -1.416887 -0.920181      -0.656293
# 3   -0.331804   0.598886  1.015071 -1.416887 -0.742849      -0.341997
# 5    0.595840   0.464819  1.015071 -0.700916 -0.210853      -0.336675
# 6    0.827751   1.671426 -0.985152 -1.416887  0.143811       5.329738
# 7    1.291572  -0.585377 -0.985152  1.446998 -0.742849      -0.594624
# 8   -1.027537   1.738460  1.015071  1.446998 -0.033521      -0.826276
# 9    0.827751  -0.920546  1.015071  0.015055 -0.565517       0.199570
# 10  -1.027537   0.174339 -0.985152 -0.700916 -0.920181      -0.826276
# 11   0.827751  -0.384276  1.015071  0.731026 -0.920181       0.315083
#
#     towers_damage  rooms_damage    deaths  money_total  kill_death_ratio  \
# 0       -0.422104     -0.243388  1.079311    -0.493218         -0.631880
# 2       -0.656259     -0.656293 -0.576446    -0.532949         -0.491786
# 3       -0.775762     -0.341997  0.085857    -0.780259         -0.690867
# 5        0.660454     -0.336675 -0.576446     0.193147         -0.027264
# 6        1.093912      5.329738 -0.907597    -0.047830          0.459378
# 7       -0.830216     -0.594624 -1.569900    -1.553571          0.370898
# 8       -0.916750     -0.826276  1.410462    -1.005977         -0.717411
# 9       -0.604477      0.199570 -0.245295    -0.459245         -0.478514
# 10      -0.229632     -0.826276  1.410462    -0.676901         -0.823587
# 11      -0.487053      0.315083  1.741614    -0.185736         -0.787391
#
#     kills_total     level  controlling_time  total_damage  earned_damage  \
# 0     -0.857765 -0.348308          0.005235     -0.263822       0.363075
# 2     -0.394431 -0.769585         -0.562991     -0.154760      -1.152349
# 3     -0.857765 -0.769585         -0.349906     -0.904240      -0.906962
# 5      0.300569  0.072968         -0.349906      0.156159       1.894751
# 6      0.300569 -0.769585         -0.562991      0.078688      -1.353423
# 7     -1.089432 -1.612137         -0.136821     -1.413538      -1.822091
# 8     -1.089432 -0.769585          2.136084     -1.210600       0.319671
# 9     -0.394431 -0.769585          0.005235     -0.120769      -0.783410
# 10    -0.857765 -0.348308         -0.491963     -0.158780       1.731025
# 11    -0.394431  0.072968         -0.847105      0.026558       2.001042
#
#     special_enemy_killed  room_kills  main_score  win_or_defeat
# 0               0.336919   -0.024765   -0.438784              0
# 2               0.563839   -0.786357   -0.917862              0
# 3               0.098057   -0.024765   -0.917862              0
# 5              -1.120144   -0.024765   -0.630415              1
# 6               0.229431    2.260014   -1.013678              1
# 7              -1.144031   -0.786357    0.375651              0
# 8              -1.084315   -0.786357    2.914769              0
# 9               0.492180   -0.024765   -0.726231              0
# 10             -1.215690   -0.786357   -0.055520              0
# 11              0.683271   -0.786357   -0.822047              0

# %% [markdown]
# # Step3: Linear Discriminant Analysis (LDA)

# %% [markdown]
# ### Split data to train and test sets. (3 points)

# %%
# TODO: Remove the target variable 'win_or_defeat' from the dataset to create feature matrix
df1 = None  

# TODO: Convert the feature matrix and target variable into numpy arrays
x = None  
y = None  

# TODO: Split the dataset into training and testing sets (80% train, 20% test)
x_train, x_test, y_train, y_test = None

# %% [markdown]
# ### Implement LDA from scratch class. (15 points)

# %%
# TODO: Implement LDA from scratch
class CustomLDA:
    def __init__(self, n_components=None):
        self.n_components = n_components

    def fit(self, X, y):
        # TODO: Get the number of samples and features
        n_samples, n_features = None  

        # TODO: Identify unique classes and their counts in y
        classes, cls_counts = None  

        # TODO: Compute prior probabilities of each class
        priors = None  

        # TODO: Compute class-wise means
        X_cls_mean = None  # 📣

        # TODO: Compute between-class and within-class deviations
        between_cls_deviation = None  # 📣
        within_cls_deviation = None  # 📣

        # TODO: Compute between-class scatter matrix (Sb) and within-class scatter matrix (Sw)
        Sb = None  # 📣
        Sw = None  # 📣

        # TODO: Solve the generalized eigenvalue problem
        evals, evecs = None  # 📣

        # TODO: Sort eigenvectors by descending eigenvalues
        self.dvecs = None  

        # TODO: Compute the weight matrix
        self.weights = None  # 📣

        # TODO: Compute the bias term
        self.bias = None  # 📣

        # TODO: Set the number of components if not specified
        if self.n_components is None:
            self.n_components = None  

    def transform(self, X):
        # TODO: Project the data onto the selected components
        return None  # 📣

    def predict(self, X_test):
        # TODO: Compute classification scores
        scores = None  # 📣

        # TODO: Assign each sample to the class with the highest score
        return None

# %% [markdown]
# ### Fit your custom LDA on data and test the model. Print the accuracy score. (5 points)

# %%
# TODO: Initialize your custom LDA model and fit it on the data


# TODO: Predict the labels for the test data
lda_pred_res = None  

# TODO: Transform the training data using LDA
transformed = None  

# TODO: Compute the accuracy score of the custom LDA model
lda_accuracy = None  

print(f'LDA accuracy: {lda_accuracy}')
# Out:
# LDA accuracy: 0.8223185265438786

# %% [markdown]
# ### Now, use the sklearn LDA model and fit ot on data and print the results. (4 points)

# %%
# TODO: Initialize the sklearn LDA model and fit it on the data # 📣

# TODO: Predict the labels for the test data using sklearn LDA
sk_lda_pred_res = None  

# TODO: Transform the training data using sklearn LDA
sk_transformed = None  

# TODO: Compute the accuracy score of the sklearn LDA model
sk_lda_accuracy = None  

print(f'sk LDA accuracy: {sk_lda_accuracy}')
# Out:
# sk LDA accuracy: 0.8223185265438786

# %% [markdown]
# ### Plot the prediction of your LDA. (4 points)

# %%
# TODO: Initialize and fit your custom LDA with 1 component 

# TODO: Transform the dataset using your custom LDA model
X_lda_custom = None  

# TODO: Plot the LDA projection of data
plt.figure(figsize=(8, 5))
sns.histplot(x=None, hue=None, bins=30, kde=True, palette="coolwarm", alpha=0.7)
plt.xlabel("Custom LDA Projection")
plt.title("Custom LDA 1D Projection of Data")
plt.show()

# %% [markdown]
# ### You can see the results are not accurate. Why this happend? When LDA is suitable to be used as a model for calssification task? (5 points)

# %% [markdown]
# ```
# Your Answer
# ```

# %% [markdown]
# # Multicalss Classification (35 points)
# In this part, you will use your LDA from scratch for multiclass classification task on starts dataset.

# %%
df = pd.read_csv('Stars.csv')
df.head(10)
# Out:
#    Temperature         L       R    A_M Color Spectral_Class  Type
# 0         3068  0.002400  0.1700  16.12   Red              M     0
# 1         3042  0.000500  0.1542  16.60   Red              M     0
# 2         2600  0.000300  0.1020  18.70   Red              M     0
# 3         2800  0.000200  0.1600  16.65   Red              M     0
# 4         1939  0.000138  0.1030  20.06   Red              M     0
# 5         2840  0.000650  0.1100  16.98   Red              M     0
# 6         2637  0.000730  0.1270  17.22   Red              M     0
# 7         2600  0.000400  0.0960  17.40   Red              M     0
# 8         2650  0.000690  0.1100  17.45   Red              M     0
# 9         2700  0.000180  0.1300  16.05   Red              M     0

# %% [markdown]
# ## Preprocessing of Data
#
# Do preprocessing on data (use Step2 methods). (4 points)

# %%
# TODO: Extract features (X) and target variable (y) from the dataset
X, y = None, None  

# TODO: Identify categorical features
cat_features_list = None  

# TODO: Encode categorical features using LabelEncoder
X[cat_features_list] = None  

# TODO: Normalize the 'Temperature' column
X1 = X.copy()
X1['Temperature'] = None  

# TODO: Convert features and target variable to numpy arrays
X, y = None, None

# %% [markdown]
# ### Split data to train and test sets.

# %%
# TODO
x_train, x_test, y_train, y_test = None

# %% [markdown]
# ### Fit your custom LDA on data and test the model. Print the accuracy score. (4 points)

# %%
# TODO: Initialize the Custom LDA model and fit it to the data

# TODO: Predict on the test data
lda_pred_res = None  

# TODO: Transform the training data using LDA
transformed = None  

# TODO: Compute the accuracy score
lda_accuracy = None  

print(f'LDA accuracy: {lda_accuracy}')
# Out:
# LDA accuracy: 1.0

# %% [markdown]
# ### Feature Selection (7 points)
# As you saw, using LDA on this data gives us 100 accuracy for classification task. Now, use the mutual information and RFE methods to select important features from first four features.

# %%
# TODO: Compute mutual information scores for the first four features
mi_scores = None  # 📣

# TODO: Create a dictionary mapping feature names to their mutual information scores
mi_scores_dict = None  

# TODO: Perform Recursive Feature Elimination (RFE) with LDA
lda = None  # 📣
rfe = None  # 📣
rfe.fit(None, None)  

# TODO: Extract selected features
selected_features = None  # 📣

print(selected_features)
# Out:
# ['Temperature', 'A_M']

# %% [markdown]
# ### Now, to see how effective are these selected features, apply LDA on the data using these features and plot the bounderies. (10 points)

# %%
# TODO: Separate features (X) and target (y) from the dataset
X, y = None

# TODO: Identify categorical features in the dataset
cat_features_list = None

# TODO: Encode categorical features into numerical values
X[cat_features_list] = None

# TODO: Convert X and y into numpy arrays and encode the target variable
X, y = None

# TODO: Split the data into training and testing sets
x_train, x_test, y_train, y_test = None

# TODO: Select the feature indices to use for LDA
feature_indexes = None

# TODO: Initialize and fit the LDA model

from mlxtend.plotting import plot_decision_regions
# TODO: Plot the decision regions for LDA # 📣
# Out:
# /usr/local/lib/python3.11/dist-packages/mlxtend/plotting/decision_regions.py:346: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(
# <Axes: title={'center': 'LDA decision regions with selected features'}>
